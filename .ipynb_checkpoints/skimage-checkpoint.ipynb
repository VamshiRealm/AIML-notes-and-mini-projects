# %%
import numpy as np

# %%
# !pip install scikit-image
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 60.8/60.8 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.9 MB 3.3 MB/s eta 0:00:04
#     --------------------------------------- 0.2/12.9 MB 2.5 MB/s eta 0:00:06
#     --------------------------------------- 0.3/12.9 MB 2.4 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/12.9 MB 2.3 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/12.9 MB 2.2 MB/s eta 0:00:06
#    - -------------------------------------- 0.6/12.9 MB 2.2 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/12.9 MB 2.2 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/12.9 MB 2.2 MB/s eta 0:00:06
# ...

# %%
import skimage

# %%
img  = skimage.io.imread("C:/Users/vamsh/Pictures/party_ledha _pushpa.jpg", as_gray=True) 
#as_gray removes all color to make it a 2d array, you can remove as_gray that would add original color back increasing the dimensions
img
# Out:
# array([[0.04219098, 0.04219098, 0.04219098, ..., 0.04138824, 0.04138824,
#         0.04138824],
#        [0.14639176, 0.14582627, 0.14639176, ..., 0.16239137, 0.16041922,
#         0.16239137],
#        [0.09090941, 0.09034392, 0.09090941, ..., 0.11671647, 0.11474431,
#         0.11671647],
#        ...,
#        [0.1125051 , 0.1125051 , 0.1125051 , ..., 0.69315804, 0.70492275,
#         0.71276588],
#        [0.1125051 , 0.1125051 , 0.1125051 , ..., 0.68923647, 0.70492275,
#         0.70884431],
#        [0.1125051 , 0.1125051 , 0.1125051 , ..., 0.68980196, 0.70156667,
#         0.7094098 ]])

# %%
img.shape
# Out:
# (479, 640)

# %%
skimage.io.imshow(img)

# %%
trans = img.T   
# .T - transponse of the image

# %%
skimage.io.imshow(trans)

# %%
# we can do essential martix operations on the image
