# %% [raw]
# SVM Algorithm:
#     Goal : Build an optimal hyperplane which can seperate classes clearly
#         How : Use *support vectors* to select the best line of divide
#     *Suitable when we don't know the datatype of the data model.*
#     Can be used for both regression and classification problems.
