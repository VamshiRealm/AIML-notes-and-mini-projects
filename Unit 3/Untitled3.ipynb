# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/vamsh/Downloads/classi-titanic.csv")

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age
# 0         0       3    male  22.0
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 4         0       3    male  35.0

# %%
data.shape
# Out:
# (714, 4)

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data["Sex"] = le.fit_transform(data["Sex"])

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age
# 0         0       3    1  22.0
# 1         1       1    0  38.0
# 2         1       3    0  26.0
# 3         1       1    0  35.0
# 4         0       3    1  35.0

# %%
from sklearn.model_selection import train_test_split
x = data.drop('Survived', axis=1)
y = data['Survived']
xtrain, xtest, ytrain, ytest = train_test_split(x, y, train_size = 0.7, random_state = 40, shuffle = True)

# %%
print(xtrain.shape)
print(xtest.shape)
# Out:
# (499, 3)
# (215, 3)

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

# %%
rfm = RandomForestClassifier()
rfm.fit(xtrain, ytrain)
pred = rfm.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(ytest, pred)
acc
# Out:
# 0.8

# %%
print(len(rfm.estimators_))
k =rfm.estimators_[8]
# Out:
# 100

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
plot_tree(k)
plt.show()

# %%
adam = AdaBoostClassifier()
adam.fit(xtrain, ytrain)
pred = adam.predict(xtest)
from sklearn.metrics import accuracy_score, confusion_matrix
acc=accuracy_score(ytest, pred)
print(acc)
print(confusion_matrix(ytest, pred))
# Out:
# 0.7813953488372093
# [[94 25]
#  [22 74]]
# C:\Users\vamsh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
