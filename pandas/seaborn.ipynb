# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns   #derived class of matplotlib superclass

# %% [markdown]
# <!-- Single Numeric Variable -->

# %%
import pandas as pd  #pan: panel, da: data, s: series

# %%
df = pd.read_csv("C:/Users/vamsh/Downloads/Salaries.csv", sep=",")
df
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035
#
# [397 rows x 7 columns]

# %% [markdown]
# # Single Numeric Variable

# %%
sns.histplot(data=df, x="salary")
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.histplot(data = df, x="salary", kde=True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.boxplot(data=df, x = "salary")
# Out:
# <Axes: xlabel='salary'>

# %% [markdown]
# # Categorical variable plotting

# %%
sns.countplot(data = df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      358
# Female     39
# Name: count, dtype: int64

# %% [markdown]
# # Line Plot

# %%
sns.lineplot(data=df, x=df.index, y = "salary")
# Out:
# <Axes: xlabel='None', ylabel='salary'>

# %% [markdown]
# # Two vaariables (Bi Variates)

# %%
sns.relplot(data=df, x="yrs.service", y = "salary")

# %%
sns.regplot(data = df, x="yrs.service", y = "salary")
# Out:
# <Axes: xlabel='yrs.service', ylabel='salary'>

# %%
sns.regplot(data = df, x="yrs.service", y = "yrs.since.phd")
# Out:
# <Axes: xlabel='yrs.service', ylabel='yrs.since.phd'>

# %% [markdown]
# # Numerical vs Categorical Variable

# %%
sns.barplot(data = df, x='sex', y = 'salary')
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %%
sns.barplot(data = df, x='sex', y = 'salary', hue= "rank")
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %%
sns.swarmplot(data = df, x='sex', y = 'salary', hue= "rank")
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %%
sns.stripplot(data = df, x='sex', y = 'salary', hue= "rank")
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %%
sns.violinplot(data = df, x='sex', y = 'salary', hue= "rank")  #merges box plot and categorical plot together
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %%
sns.catplot(data = df, x='sex', y = 'salary', hue= "rank", kind="swarm") # catplot can be used in general for differnt kind of plottings

# %% [markdown]
# # Multiple variables

# %%
sns.pairplot(data = df)

# %%
df.corr(numeric_only = True)
# Out:
#                Unnamed: 0  yrs.since.phd  yrs.service    salary
# Unnamed: 0       1.000000       0.208424     0.166314  0.099583
# yrs.since.phd    0.208424       1.000000     0.909649  0.419231
# yrs.service      0.166314       0.909649     1.000000  0.334745
# salary           0.099583       0.419231     0.334745  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
"""Building a Good Training Set
1. Removing and imputing missing values from the dataset
    values Represented as NaN or NaT
    methods that can be used:
    a. Dropping the entire row or column 
    b. Entering the values in the required field
2. Getting the data into a shape for ML Algorithms
3. Selecting the relevant features for model construction (feature selection or feature extraction)"""
# Out:
# 'Building a Good Training Set\n1. Removing and imputing missing values from the dataset\n    values Represented as NaN or NaT\n    methods that can be used:\n    a. Dropping the entire row or column \n    b. Entering the values in the required field\n2. Getting the data into a shape for ML Algorithms\n3. Selecting the relevant features for model construction (feature selection or feature extraction)'

# %%
df = pd.read_csv("C:/Users/vamsh/Downloads/Iris-f.csv")

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              NaN           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# SepalLengthCm    2
# SepalWidthCm     1
# PetalLengthCm    1
# PetalWidthCm     0
# Species          1
# dtype: int64

# %%
df.count()
# Out:
# SepalLengthCm    148
# SepalWidthCm     149
# PetalLengthCm    149
# PetalWidthCm     150
# Species          149
# dtype: int64

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# # Duplicate Record Removal

# %% [markdown]
# <!-- Duplicate Record Removal -->

# %% [markdown]
# <!-- Duplicate Record Removal -->

# %% [markdown]
# <!-- Diplicate Record Removal -->

# %%
df[df.duplicated()]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 34             4.9           3.1            1.5           0.1     Iris-setosa
# 37             4.9           3.1            1.5           0.1     Iris-setosa
# 142            5.8           2.7            5.1           1.9  Iris-virginica

# %%
df = df.drop([34,37,142], axis=0)

# %%
df.shape
# Out:
# (147, 5)

# %%
df.isna().sum()
# Out:
# SepalLengthCm    2
# SepalWidthCm     1
# PetalLengthCm    1
# PetalWidthCm     0
# Species          1
# dtype: int64

# %%
df1 = df.copy(deep=True)

# %%
df1.shape
# Out:
# (147, 5)

# %% [markdown]
# # Missing Value treatment

# %%
df1.dropna(axis = 0, inplace=True) #  dropna drops the row(axis = 0) only if it is none value
                                     # Inplace acts just as assigning it to impact it in real df1 data

# %%
df1.shape
# Out:
# (143, 5)

# %%
df1.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Taking another copy of original data for another method
df2 = df.copy(deep=True)

# %%
df2.shape
# Out:
# (147, 5)

# %% [markdown]
# # Inserting the values

# %%
m = df2['SepalLengthCm'].mean()
df2['SepalLengthCm'] = df2['SepalLengthCm'].fillna(m)

# %%
df2.head
# Out:
# <bound method NDFrame.head of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0         5.100000           3.5            1.4           0.2     Iris-setosa
# 1         4.900000           3.0            1.4           0.2     Iris-setosa
# 2         4.700000           3.2            1.3           0.2     Iris-setosa
# 3         4.600000           3.1            1.5           0.2     Iris-setosa
# 4         5.865517           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145       6.700000           3.0            5.2           2.3  Iris-virginica
# 146       6.300000           2.5            5.0           1.9  Iris-virginica
# 147       6.500000           3.0            5.2           2.0  Iris-virginica
# 148       6.200000           3.4            5.4           2.3  Iris-virginica
# 149       5.900000           3.0            5.1           1.8  Iris-virginica
#
# ...

# %%
# Inserting categorical values
df3 = df2.iloc[:, 0:4]

# %%
df3.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0       5.100000           3.5            1.4           0.2
# 1       4.900000           3.0            1.4           0.2
# 2       4.700000           3.2            1.3           0.2
# 3       4.600000           3.1            1.5           0.2
# 4       5.865517           3.6            1.4           0.2

# %%
df3 = df3.fillna(df3.mean())

# %%
df3.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# dtype: int64

# %%
df3.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0       5.100000           3.5            1.4           0.2
# 1       4.900000           3.0            1.4           0.2
# 2       4.700000           3.2            1.3           0.2
# 3       4.600000           3.1            1.5           0.2
# 4       5.865517           3.6            1.4           0.2

# %%
# Adding previous column to the current copy of df3 (from df)
df3['Species'] = df['Species']

# %% [markdown]
# df3.shape

# %%
df3.shape
# Out:
# (147, 5)

# %%
df3.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          1
# dtype: int64

# %%
df.shape
# Out:
# (147, 5)

# %%
df3["Species"].mode()  #mode can be used for categorical filling of data : mode
# Out:
# 0    Iris-versicolor
# Name: Species, dtype: object

# %%
df3["Species"] = df3["Species"].fillna("Iris-versicolor")

# %%
df3.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
