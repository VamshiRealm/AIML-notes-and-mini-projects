# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.9 MB 2.6 MB/s eta 0:00:05
#     --------------------------------------- 0.2/10.9 MB 2.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/10.9 MB 2.2 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/10.9 MB 2.2 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/10.9 MB 2.2 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/10.9 MB 2.2 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/10.9 MB 2.1 MB/s eta 0:00:05
#    -- ------------------------------------- 0.8/10.9 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 0.9/10.9 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 1.0/10.9 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 1.1/10.9 MB 2.1 MB/s eta 0:00:05
# ...

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# %%
s1 = SimpleImputer(missing_values= np.nan, strategy='mean')

# %%
import pandas as pd
df = pd.read_csv("C:/Users/vamsh/Downloads/Iris-f.csv")

# %%
df1 = df.iloc[:, 0:4]

# %%
new_array = s1.fit_transform(df1)

# %%
new_array
# Out:
# array([[5.1       , 3.5       , 1.4       , 0.2       ],
#        [4.9       , 3.        , 1.4       , 0.2       ],
#        [4.7       , 3.2       , 1.3       , 0.2       ],
#        [4.6       , 3.1       , 1.5       , 0.2       ],
#        [5.85202703, 3.6       , 1.4       , 0.2       ],
#        [5.4       , 3.9       , 1.7       , 0.4       ],
#        [4.6       , 3.4       , 1.4       , 0.3       ],
#        [5.        , 3.05167785, 3.7738255 , 0.2       ],
#        [4.4       , 2.9       , 1.4       , 0.2       ],
#        [4.9       , 3.1       , 1.5       , 0.1       ],
#        [5.4       , 3.7       , 1.5       , 0.2       ],
#        [4.8       , 3.4       , 1.6       , 0.2       ],
#        [4.8       , 3.        , 1.4       , 0.1       ],
#        [4.3       , 3.        , 1.1       , 0.1       ],
#        [5.8       , 4.        , 1.2       , 0.2       ],
#        [5.7       , 4.4       , 1.5       , 0.4       ],
# ...

# %%
df2 = pd.DataFrame(new_array, columns=["Sepal_Len","Sepal_width","Petal_Len","Petal_width"])

# %%
df2
# Out:
#      Sepal_Len  Sepal_width  Petal_Len  Petal_width
# 0     5.100000          3.5        1.4          0.2
# 1     4.900000          3.0        1.4          0.2
# 2     4.700000          3.2        1.3          0.2
# 3     4.600000          3.1        1.5          0.2
# 4     5.852027          3.6        1.4          0.2
# ..         ...          ...        ...          ...
# 145   6.700000          3.0        5.2          2.3
# 146   6.300000          2.5        5.0          1.9
# 147   6.500000          3.0        5.2          2.0
# 148   6.200000          3.4        5.4          2.3
# 149   5.900000          3.0        5.1          1.8
#
# [150 rows x 4 columns]

# %%
df3 = df.copy(deep=True)

# %%
df3['SepalLengthCm'] = df3['SepalLengthCm'].fillna(method='bfill')
# Out:
# C:\Users\vamsh\AppData\Local\Temp\ipykernel_14756\2571145109.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df3['SepalLengthCm'] = df3['SepalLengthCm'].fillna(method='bfill')

# %%
df3
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.4           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]
