# %% [raw]
# Feature Scaling: Bringing data into same scale

# %% [raw]
# Methods:
# 1. Normalization (MinMaxScaler) : Rescale the data with a fixed minimum and maximum ( values would be in between 0 to 1)
# 2. Standardization (StandardScaler): Use stastical measure to map the features (mean and standard deviation) ( values would be in minus range to some                                      positive range but the range will be short)
# 3. Binarization (Binarizer): Convert numeric values in categorical values and mainly used in *image processing* by using a threshold as a base for                                 classification.
#                              In images threshold is 127 (all colours range from 0 to 255)

# %%
import pandas as pd
df = pd.read_csv("C:/Users/vamsh/Downloads/Iris-f.csv")

# %%
from sklearn.preprocessing import MinMaxScaler
mmscaler = MinMaxScaler()
mmscaler.fit_transform(df.iloc[:,0:4])
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [       nan, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444,        nan,        nan, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
from sklearn.preprocessing import StandardScaler
mmscaler = StandardScaler()
mmscaler.fit_transform(df.iloc[:,0:4])
# Out:
# array([[-9.09218146e-01,  1.03619829e+00, -1.35289577e+00,
#         -1.31297673e+00],
#        [-1.15102279e+00, -1.19442019e-01, -1.35289577e+00,
#         -1.31297673e+00],
#        [-1.39282744e+00,  3.42814106e-01, -1.40988799e+00,
#         -1.31297673e+00],
#        [-1.51372976e+00,  1.11686044e-01, -1.29590355e+00,
#         -1.31297673e+00],
#        [            nan,  1.26732636e+00, -1.35289577e+00,
#         -1.31297673e+00],
#        [-5.46511177e-01,  1.96071054e+00, -1.18191912e+00,
#         -1.05003079e+00],
#        [-1.51372976e+00,  8.05070232e-01, -1.35289577e+00,
#         -1.18150376e+00],
#        [-1.03012047e+00,             nan,             nan,
#         -1.31297673e+00],
#        [-1.75553441e+00, -3.50570082e-01, -1.35289577e+00,
#         -1.31297673e+00],
#        [-1.15102279e+00,  1.11686044e-01, -1.29590355e+00,
#         -1.44444970e+00],
#        [-5.46511177e-01,  1.49845442e+00, -1.29590355e+00,
#         -1.31297673e+00],
# ...

# %%
from sklearn.preprocessing import Binarizer
mmscaler = Binarizer(threshold = 2)
mmscaler.fit_transform(df.iloc[:,0:4])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 from sklearn.preprocessing import Binarizer
#       2 mmscaler = Binarizer(threshold = 2)
# ----> 3 mmscaler.fit_transform(df.iloc[:,0:4])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
mmscaler = MinMaxScaler(feature_range=(1,7))
mmscaler.fit_transform(df.iloc[:,0:4])
# Out:
# array([[2.33333333, 4.75      , 1.40677966, 1.25      ],
#        [2.        , 3.5       , 1.40677966, 1.25      ],
#        [1.66666667, 4.        , 1.30508475, 1.25      ],
#        [1.5       , 3.75      , 1.50847458, 1.25      ],
#        [       nan, 5.        , 1.40677966, 1.25      ],
#        [2.83333333, 5.75      , 1.71186441, 1.75      ],
#        [1.5       , 4.5       , 1.40677966, 1.5       ],
#        [2.16666667,        nan,        nan, 1.25      ],
#        [1.16666667, 3.25      , 1.40677966, 1.25      ],
#        [2.        , 3.75      , 1.50847458, 1.        ],
#        [2.83333333, 5.25      , 1.50847458, 1.25      ],
#        [1.83333333, 4.5       , 1.61016949, 1.25      ],
#        [1.83333333, 3.5       , 1.40677966, 1.        ],
#        [1.        , 3.5       , 1.10169492, 1.        ],
#        [3.5       , 6.        , 1.20338983, 1.25      ],
#        [3.33333333, 7.        , 1.50847458, 1.75      ],
# ...
